# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\asus\Downloads\CricketTestMatchData.csv')

# %%
df.head()
# Out:
#              Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0  DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2    AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3   RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4   GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
#
#       SR  100  50  0    4s  6s
# 0  58.60   29  13  7  626+   6
# 1  91.76    4   7  1   141  23
# 2  55.68    5   4  2   186   5
# 3  54.48    7  11  1  246+  11
# 4  56.00   10   5  2  104+   1

# %%
df=df.rename(columns={'Mat':'Matches','NO':'Not_Outs','HS':'Highest_Inns_Score','BF':'Balls_Faced','SR':'Batting_Strike_Rate'})

# %%
df
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1      HC Brook (ENG)  2022-2023       12    20         1  1181
# 2      AC Voges (AUS)  2015-2016       20    31         7  1485
# 3     RG Pollock (SA)  1963-1970       23    41         4  2256
# 4     GA Headley (WI)  1930-1954       22    40         4  2190
# ..                ...        ...      ...   ...       ...   ...
# 59   KD Walters (AUS)  1965-1981       74   125        14  5357
# 60  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 61  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 62    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 63   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# ...

# %% [markdown]
# Check null value

# %%
df.isnull().any()
# Out:
# Player                 False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country                False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#                   Player       Span  Matches  Inns  Not_Outs  Runs  \
# 9         ED Weekes (WI)  1948-1958       48    81         5  4455
# 16       CL Walcott (WI)  1948-1960       44    74         7  3798
# 56  Hon.FS Jackson (ENG)  1893-1905       20    33         4  1415
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 9                 207  58.61         NaN                  NaN   15  19  6
# 16                220  56.68         NaN                  NaN   15  14  1
# 56               144*  48.79         NaN                  NaN    5   6  3
#
#       4s  6s
# 9   258+   2
# 16  107+  11
# 56   51+   0

# %% [markdown]
# Fill the null value with '0'

# %%
df['Balls_Faced']=df['Balls_Faced'].fillna(0)

# %%
df['Batting_Strike_Rate']=df['Batting_Strike_Rate'].fillna(0)

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced            False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 6   H Sutcliffe (ENG)  1924-1935       54    84         9  4555
# 15     JB Hobbs (ENG)  1908-1930       61   102         7  5410
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 6                 194  60.73       6558+                34.59   16  23  2
# 15                211  56.94       5363+                46.22   15  28  4
#
#       4s 6s
# 6   202+  6
# 15  276+  8

# %%
#delete the dublicates value
df = df.drop_duplicates()

# %% [markdown]
# Split up Span into Start and End Date

# %%
df['Span'].str.split(pat='-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 59    [1965, 1981]
# 60    [2002, 2014]
# 61    [1924, 1934]
# 62    [1930, 1938]
# 63    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df['Rookie_Year']=df['Span'].str.split(pat='-').str[0]
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_6152\1740907504.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rookie_Year']=df['Span'].str.split(pat='-').str[0]

# %%
df['Final_Year']=df['Span'].str.split(pat='-').str[1]
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_6152\1405677318.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Final_Year']=df['Span'].str.split(pat='-').str[1]

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 59   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 60  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 61  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 62    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 63   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s Rookie_Year Final_Year
# ...

# %%
df=df.drop(['Span'],axis=1)

# %%
df.head()
# Out:
#              Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0  DG Bradman (AUS)       52    80        10  6996                334  99.94
# 1    HC Brook (ENG)       12    20         1  1181                186  62.15
# 2    AC Voges (AUS)       20    31         7  1485               269*  61.87
# 3   RG Pollock (SA)       23    41         4  2256                274  60.97
# 4   GA Headley (WI)       22    40         4  2190               270*  60.83
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s Rookie_Year  \
# 0       9800+                58.60   29  13  7  626+   6        1928
# 1        1287                91.76    4   7  1   141  23        2022
# 2        2667                55.68    5   4  2   186   5        2015
# 3       1707+                54.48    7  11  1  246+  11        1963
# 4        416+                56.00   10   5  2  104+   1        1930
#
#   Final_Year
# 0       1948
# 1       2023
# 2       2016
# 3       1970
# 4       1954

# %%
df['Player'].str.split(pat='(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [HC Brook , ENG)]
# 2        [AC Voges , AUS)]
# 3       [RG Pollock , SA)]
# 4       [GA Headley , WI)]
#               ...
# 59     [KD Walters , AUS)]
# 60    [GC Smith , ICC/SA)]
# 61    [WH Ponsford , AUS)]
# 62      [SJ McCabe , AUS)]
# 63     [DR Jardine , ENG)]
# Name: Player, Length: 62, dtype: object

# %%
df['Country']=df['Player'].str.split(pat='(').str[1]

# %%
df['Country'] = df['Country'].str.split(pat=')').str[0]

# %%
df['Country']
# Out:
# 0        AUS
# 1        ENG
# 2        AUS
# 3         SA
# 4         WI
#        ...
# 59       AUS
# 60    ICC/SA
# 61       AUS
# 62       AUS
# 63       ENG
# Name: Country, Length: 62, dtype: object

# %%
df['Player']=df['Player'].str.split(pat='(').str[0]

# %%
df
# Out:
#           Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0    DG Bradman        52    80        10  6996                334  99.94
# 1      HC Brook        12    20         1  1181                186  62.15
# 2      AC Voges        20    31         7  1485               269*  61.87
# 3    RG Pollock        23    41         4  2256                274  60.97
# 4    GA Headley        22    40         4  2190               270*  60.83
# ..           ...      ...   ...       ...   ...                ...    ...
# 59   KD Walters        74   125        14  5357                250  48.26
# 60     GC Smith       117   205        13  9265                277  48.25
# 61  WH Ponsford        29    48         4  2122                266  48.22
# 62    SJ McCabe        39    62         5  2748                232  48.21
# 63   DR Jardine        22    33         6  1296                127  48.00
#
#    Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s Rookie_Year  \
# ...

# %%
df['Highest_Inns_Score']= df['Highest_Inns_Score'].str.split(pat='*').str[0]

# %%
df['Highest_Inns_Score']=df['Highest_Inns_Score'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df.astype({'Rookie_Year':'int','Final_Year':'int'})
# Out:
#           Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 0    DG Bradman        52    80        10  6996                 334  99.94
# 1      HC Brook        12    20         1  1181                 186  62.15
# 2      AC Voges        20    31         7  1485                 269  61.87
# 3    RG Pollock        23    41         4  2256                 274  60.97
# 4    GA Headley        22    40         4  2190                 270  60.83
# ..           ...      ...   ...       ...   ...                 ...    ...
# 59   KD Walters        74   125        14  5357                 250  48.26
# 60     GC Smith       117   205        13  9265                 277  48.25
# 61  WH Ponsford        29    48         4  2122                 266  48.22
# 62    SJ McCabe        39    62         5  2748                 232  48.21
# 63   DR Jardine        22    33         6  1296                 127  48.00
#
# ...

# %%
df['4s']=df['4s'].str.split(pat='+').str[0]

# %%
df['6s']=df['6s'].str.split(pat='+').str[0]

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df.isna().any()
# Out:
# Player                 False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced            False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country                False
# dtype: bool

# %%
df=df.astype({'Final_Year':'int','Rookie_Year':'int'})

# %%
df['career_length']=df['Final_Year']-df['Rookie_Year']

# %% [markdown]
# Avg Baating strike rate for cricketer who played over 10 year

# %%
df[df['career_length']>10]['Batting_Strike_Rate'].mean()
# Out:
# 47.94681818181819

# %% [markdown]
# no of cricketeres who player before 1960

# %%
df[df['Rookie_Year']<1960]['Player'].count()
# Out:
# 23

# %% [markdown]
# Max highest inns score by country

# %%
df.groupby('Country')['Highest_Inns_Score'].max().to_frame('High').sort_values('High',ascending=False)
# Out:
#          High
# Country
# ICC/WI    400
# AUS       380
# SL        374
# WI        365
# ENG       364
# ICC/PAK   329
# ICC/IND   319
# PAK       313
# SA        278
# ICC/SA    277
# IND       254
# NZ        251
# ZIM       232
